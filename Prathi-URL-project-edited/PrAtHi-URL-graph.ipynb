# %%
import pandas as pd

# %%
traindata = pd.read_csv('logs/cnnlstm/cnnlstmanalysis.csv')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
print(traindata.keys())
# Out:
# Index([u'epoch', u'acc', u'loss', u'val_acc', u'val_loss'], dtype='object')

# %%
# summarize history for accuracy
plt.plot(traindata['acc'])
plt.plot(traindata['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(traindata['loss'])
plt.plot(traindata['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
